# %% [markdown]
# <a href="https://colab.research.google.com/github/Mobad225/S-DCNet/blob/master/Crowd_Counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/Mobad225/S-DCNet/archive/master.zip
# Out:
# --2020-12-26 17:08:38--  https://github.com/Mobad225/S-DCNet/archive/master.zip
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/Mobad225/S-DCNet/zip/master [following]
# --2020-12-26 17:08:38--  https://codeload.github.com/Mobad225/S-DCNet/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.255.121
# Connecting to codeload.github.com (codeload.github.com)|192.30.255.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [ <=>                ]  13.33K  --.-KB/s    in 0.006s
#
# 2020-12-26 17:08:39 (2.05 MB/s) - ‘master.zip’ saved [13647]

# %%
# !unzip -q master.zip

# %%
# %cd S-DCNet-master
# Out:
# /content/S-DCNet-master

# %%
# !gdown https://drive.google.com/uc?id=1q7ESNoB8cYJTANEuiNlVf8toPSfI81m7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1q7ESNoB8cYJTANEuiNlVf8toPSfI81m7
# To: /content/S-DCNet-master/Test_Data.zip
# 314MB [00:01, 178MB/s]

# %%
# !unzip -q Test_Data.zip

# %%
# !gdown https://drive.google.com/uc?id=1gK-aqEpWm2io11_CBzCX3F0EVJcFju25
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gK-aqEpWm2io11_CBzCX3F0EVJcFju25
# To: /content/S-DCNet-master/model.zip
# 210MB [00:01, 195MB/s]

# %%
# !unzip -q model.zip

# %%
# %matplotlib inline
# %run SHAB_main.py
# Out:
# ...
# Begin to test for SH_partA_Density_map
# Test:[    1/  182] pre: 162.757 gt:170.000 err:-7.243 frame: 14.69Hz/14.69Hz
# Test:[    2/  182] pre: 207.754 gt:249.000 err:-41.246 frame: 4.15Hz/9.42Hz
# Test:[    3/  182] pre: 893.720 gt:823.000 err:70.720 frame: 5.15Hz/8.00Hz
# Test:[    4/  182] pre: 400.177 gt:429.000 err:-28.823 frame: 4.01Hz/7.00Hz
# Test:[    5/  182] pre: 198.970 gt:199.000 err:-0.030 frame: 7.58Hz/7.12Hz
# Test:[    6/  182] pre: 164.414 gt:266.000 err:-101.586 frame: 7.84Hz/7.24Hz
# Test:[    7/  182] pre: 546.572 gt:553.000 err:-6.428 frame: 6.05Hz/7.07Hz
# Test:[    8/  182] pre: 594.539 gt:717.000 err:-122.461 frame: 5.45Hz/6.87Hz
# Test:[    9/  182] pre: 191.915 gt:230.000 err:-38.085 frame: 5.59Hz/6.72Hz
# Test:[   10/  182] pre: 167.336 gt:208.000 err:-40.664 frame: 13.64Hz/7.42Hz
# Test:[   11/  182] pre: 309.891 gt:341.000 err:-31.109 frame: 20.26Hz/8.58Hz
# Test:[   12/  182] pre: 213.320 gt:223.000 err:-9.680 frame: 24.64Hz/9.92Hz
# ...
